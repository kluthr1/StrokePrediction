# %%
import pickle
import pandas as pd
from __future__ import absolute_import, division, print_function
import tensorflow as tf
from tensorflow import keras
import requests

# Helper libraries
import numpy as np
import matplotlib.pyplot as plt
import os
from matplotlib import gridspec
from matplotlib import pyplot as plt
import numpy as np
from PIL import Image

# %%
lines = [line.rstrip('\n') for line in open('strokeSmiles')]
strokeURLs = []
for line in lines:
    strokeURLs.append( line.split('"')[1])

# %%
lines = [line.rstrip('\n') for line in open('regSmiles')]
regURLs = []
for line in lines:
    regURLs.append( line.split('"')[1])

# %%
strokeURLs.append("https://www.premierhealth.com/uploadedImages/PremierHealth/Your_Wellness/Live_Well_Stay_Well/Prevention_and_Wellness/Womens_Health/Women,_Wisdom_and_Wellness/Content/P-W-WMN53246-fast-lg.jpg?n=5517")
f = "strokes/img"
strokeURLs.append("https://i.ytimg.com/vi/jFVEUHUi3_w/maxresdefault.jpg")
strokeURLs.append("https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTd26jK-Ka8WxF28SlRIcoFh8A9jhcqhCRba9bQCEJsHA7uUN5Bww")

for i,url in enumerate(strokeURLs):
    try:
        filename = f + str(i) + ".png"
        print(url)
        result = requests.get(url, stream=True)
        if result.status_code == 200:
            image = result.raw.read()
            open(filename,"wb").write(image)
    except:
        print ("OoF")
# Out:
# https://photo-bytes.com/images/20130120-dscn6421_5.jpg
# https://i.ytimg.com/vi/WKvMkA0HzYw/hqdefault.jpg
# https://doctorstelemedicine.com/news/wp-content/uploads/2018/03/1-1.jpg
# https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSPI3cvfAQI57qBDwEvOPRjDoepWcBVnJ3hx1F0mqK90GvEE4Y2
# https://www.healthhub.sg/sites/assets/Assets/Programs/senior%20health-stroke%20awareness/images/stroke/identify/f.jpg
# https://www.jems.com/content/jems/en/articles/print/volume-39/issue-5/features/differentiating-facial-weakness-caused-b/_jcr_content/leftcolumn/article/thumbnailimage.img.jpg
# http://www.womens-health-advice.com/assets/images/stroke-symptoms.jpg
# https://media.istockphoto.com/photos/portrait-of-senior-man-suffering-from-stroke-picture-id647711962?k=6&m=647711962&s=612x612&w=0&h=3E0AuXRNktY8KDYOTCXtCsD3bAnIKskCeX-CBY4BeHo=
# https://i.pinimg.com/originals/74/53/31/745331f9f2b50c6538ec3ae61362e014.jpg
# ...

# %%
f = "smiles/img"
for i,url in enumerate(regURLs):
    try:
        filename = f + str(i) + ".png"
        print(url)
        result = requests.get(url, stream=True)
        if result.status_code == 200:
            image = result.raw.read()
            open(filename,"wb").write(image)
    except:
        print ("OoF")
# Out:
# https://d2v9y0dukr6mq2.cloudfront.net/video/thumbnail/e4R-RRY/person-smiling-and-happy_sqtmh7xr_thumbnail-full03.png
# https://images.pexels.com/photos/709802/pexels-photo-709802.jpeg?cs=srgb&dl=adolescent-attractive-beautiful-709802.jpg&fm=jpg
# https://www.healthworks.my/wp-content/uploads/2014/02/Smiles.jpg
# https://images.pexels.com/photos/1102341/pexels-photo-1102341.jpeg?cs=srgb&dl=beautiful-beauty-brazilian-woman-1102341.jpg&fm=jpg
# https://ak4.picdn.net/shutterstock/videos/2170574/thumb/5.jpg
# https://media4.s-nbcnews.com/j/newscms/2017_47/2233721/171120-smile-stock-njs-333p_4ecd5b9a2aefbfdfbc3331c6d474d963.fit-760w.jpg
# http://jldentalcare.co.uk/wp-content/uploads/2018/02/person-smiling.jpg
# https://img.purch.com/h/1000/aHR0cDovL3d3dy5saXZlc2NpZW5jZS5jb20vaW1hZ2VzL2kvMDAwLzA2Ny82NTQvb3JpZ2luYWwvbGF1Z2hpbmctbWFuLmpwZw==
# https://www.plowzandmowz.com/wp-content/uploads/2014/05/Smiling-Man.jpg
# https://www.projectu.tv/wp-content/uploads/2015/06/shutterstock_81301759.jpg
# ...
